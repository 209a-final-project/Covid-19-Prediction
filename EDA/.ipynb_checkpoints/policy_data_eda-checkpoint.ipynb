# %%
#RUN THIS CELL 
import requests
from IPython.core.display import HTML
styles = requests.get("https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/cs109.css").text
HTML(styles)
# Out:
# <style>
# blockquote { background: #AEDE94; }
# h1 {
#     padding-top: 25px;
#     padding-bottom: 25px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# h2 {
#     padding-top: 10px;
#     padding-bottom: 10px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
#
# div.exercise {
# 	background-color: #ffcccc;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# }
#
# div.exercise-r {
# 	background-color: #fce8e8;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# }
#
#
# span.sub-q {
# 	font-weight: bold;
# }
# div.theme {
# 	background-color: #DDDDDD;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 18pt;
# }
# div.gc {
# 	background-color: #AEDE94;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 12pt;
# }
# p.q1 {
# ...

# %%
#RUN THIS CELL
import os
import pathlib
working_dir = pathlib.Path().absolute()
os.chdir(working_dir)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Policy Data From KFF

# %%
np.random.seed(109)
socdist_df = pd.read_csv('policy-data/social_distance_policy.csv',skiprows=[0,1,3])

# %%
socdist_df
# Out:
#                 Location        Status of Reopening  \
# 0                Alabama                     Paused
# 1                 Alaska  Proceeding with Reopening
# 2                Arizona   New Restrictions Imposed
# 3               Arkansas                     Paused
# 4             California  Proceeding with Reopening
# 5               Colorado   New Restrictions Imposed
# 6            Connecticut  Proceeding with Reopening
# 7               Delaware  Proceeding with Reopening
# 8   District of Columbia  Proceeding with Reopening
# 9                Florida  Proceeding with Reopening
# 10               Georgia  Proceeding with Reopening
# 11                Hawaii   New Restrictions Imposed
# 12                 Idaho   New Restrictions Imposed
# 13              Illinois   New Restrictions Imposed
# 14               Indiana                   Reopened
# 15                  Iowa                   Reopened
# 16                Kansas                   Reopened
# ...

# %%
quarantine = socdist_df[["Location","Mandatory Quarantine for Travelers"]]
quarantine
# Out:
#                 Location   Mandatory Quarantine for Travelers
# 0                Alabama                                    -
# 1                 Alaska                        All Travelers
# 2                Arizona                               Lifted
# 3               Arkansas                               Lifted
# 4             California                                    -
# 5               Colorado                                    -
# 6            Connecticut            From Certain States (New)
# 7               Delaware                               Lifted
# 8   District of Columbia            From Certain States (New)
# 9                Florida                               Lifted
# 10               Georgia                                    -
# 11                Hawaii                        All Travelers
# 12                 Idaho                               Lifted
# 13              Illinois                                    -
# ...

# %%
quarantine["Mandatory Quarantine for Travelers"].value_counts()
# Out:
# -                                      22
# Lifted                                 16
# From Certain States (New)               4
# All Travelers                           4
# Rolled Back to Certain States           3
# From Certain States                     1
# Rolled Back to International Travel     1
# Name: Mandatory Quarantine for Travelers, dtype: int64

# %%
plt.figure(figsize = (8,5))
plt.hist(quarantine["Mandatory Quarantine for Travelers"], align='left')
plt.xticks(rotation=30)
plt.xticks(range(7))
# Out:
# ([<matplotlib.axis.XTick at 0x7fb860aa3730>,
# ...
#  <a list of 7 Text major ticklabel objects>)

# %% [markdown]
# # Quarantine Data
# Adapted from https://github.com/covidvis/covid19-vis

# %%
quan_df = pd.read_csv("policy-data/quarantine-activity-US-long.csv")

# %%
quan_df
# Out:
#        State Coverage.type Coverage.location Effective Date  \
# 0    Alabama    State-wide           Alabama        3/13/20
# 1    Alabama    State-wide           Alabama        3/27/20
# 2    Alabama    State-wide           Alabama         3/2/20
# 3    Alabama    State-wide           Alabama         4/4/20
# 4    Alabama    State-wide           Alabama        3/18/20
# ..       ...           ...               ...            ...
# 602  Wyoming    State-wide           Wyoming        3/15/20
# 603  Wyoming      Regional             Teton        3/28/20
# 604  Wyoming      Regional             Teton        3/30/20
# 605  Wyoming      Regional           Jackson        3/28/20
# 606  Wyoming      Regional           Jackson        3/31/20
#
#     State of Emergency Declaration Travel Restrictions  \
# 0      State of Emergency declared                 NaN
# 1                              NaN                 NaN
# 2                              NaN                 NaN
# ...
